# %%
# 验证环境是否正常
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# 检查数据连接（需要配置API Key）
from jqdatasdk import *
auth('19382208074', 'Zjy2805308721')
# Out:
# auth success

# %%
get_query_count()  # 获取当前查询额度
# Out:
# {'total': 1000000, 'spare': 1000000}
